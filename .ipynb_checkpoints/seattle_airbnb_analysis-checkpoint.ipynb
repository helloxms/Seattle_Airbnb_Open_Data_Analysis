# %% [markdown]
# # Seattle Airbnb Open Data Analys
#
# #### Data Description：
# since 2008,guests and hosts have used Airbnb to travel in a more unique, personalized way. As part of the Airbnb Inside initiative, this dataset describes the listing activity of homestays in Seattle, WA.

# %% [markdown]
# #### Get Data:
# The following Airbnb activity is included in this Seattle dataset:
# Listings, including full descriptions and average review score
# Reviews, including unique id for each reviewer and detailed comments
# Calendar, including listing id and the price and availability for that day

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %matplotlib inline

listings = pd.read_csv('listings.csv')
calendar = pd.read_csv('calendar.csv')
reviews = pd.read_csv('reviews.csv')

# %%
listings.sample(2,random_state=42)
# Out:
#            id                           listing_url       scrape_id  \
# 2562  8505940  https://www.airbnb.com/rooms/8505940  20160104002432
# 1425  5270886  https://www.airbnb.com/rooms/5270886  20160104002432
#
#      last_scraped                                 name  \
# 2562   2016-01-04                    Cozy room near UW
# 1425   2016-01-04  Walk To Space Needle, Pike Place S7
#
#                                                 summary  \
# 2562  This 1918 house in the Montlake district is lo...
# 1425  Experience Seattle's ultimate urban condo livi...
#
#                                                   space  \
# 2562  This beautiful 1918 home in the Montlake distr...
# 1425                                                NaN
#
#                                             description experiences_offered  \
# 2562  This 1918 house in the Montlake district is lo...                none
# 1425  Experience Seattle's ultimate urban condo livi...                none
#
#                                   neighborhood_overview        ...         \
# 2562  Montlake is a fashionable residential neighbor...        ...
# 1425  Close to everything including:  * The Space Ne...        ...
#
#      review_scores_value requires_license license jurisdiction_names  \
# 2562                10.0                f     NaN         WASHINGTON
# 1425                 9.0                f     NaN         WASHINGTON
#
#      instant_bookable cancellation_policy  require_guest_profile_picture  \
# 2562                f            moderate                              f
# 1425                f              strict                              f
#
#      require_guest_phone_verification calculated_host_listings_count  \
# 2562                                f                              2
# 1425                                t                              3
#
#      reviews_per_month
# 2562              4.20
# 1425              1.53
#
# [2 rows x 92 columns]

# %%
print("listings columns:")
print(listings.columns)
print(listings.shape)
print("calendar columns:")
print(calendar.columns)
print(calendar.shape)
print("reviews columns:")
print(reviews.columns)
print(reviews.shape)
# Out:
# listings columns:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')
# (3818, 92)
# calendar columns:
# Index(['listing_id', 'date', 'available', 'price'], dtype='object')
# (1393570, 4)
# reviews columns:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')
# (84849, 6)

# %% [markdown]
# ###### listings columns:
#
# ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'](3818, 92)
#
#
# ###### calendar columns:
# ['listing_id', 'date', 'available', 'price']
# (1393570, 4)
#
#
# ###### reviews columns:
# ['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments']
# (84849, 6)

# %%
reviews.sample(2,random_state=42)
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 41188     6637899  40956769  2015-08-03      5529156        Maggie
# 51646     5918259  47360403  2015-09-18      3381323       Melissa
#
#                                                 comments
# 41188  Eileen was totally welcoming, a lovely host, o...
# 51646  My hubby and I had a wonderful time at Dee's a...

# %%
def str_obj_to_number( str_obj):
    number = float( str(str_obj).replace(',', '').split('$')[-1])
    return number

def booleans_to_number( s):
    if s == 'f':
        return 0
    elif s == 't':
        return 1
    return None

# %%
print(calendar.columns)
print(calendar.shape)
print(calendar.dtypes)
# Out:
# Index(['listing_id', 'date', 'available', 'price'], dtype='object')
# (1393570, 4)
# listing_id     int64
# date          object
# available     object
# price         object
# dtype: object

# %%
calendar['price'] = calendar['price'].apply(str_obj_to_number)
calendar['available'] = calendar['available'].apply(booleans_to_number)
print("calendar.price dtype is :{}".format(calendar['price'].dtype))
print("calendar.available dtype is :{}".format(calendar['available'].dtype))
#calendar[calendar['listing_id'] == 8666707 & calendar['price'].notnull() ]
calendar['price'].notnull().sum()
# Out:
# calendar.price dtype is :float64
# calendar.available dtype is :int64
# 934542

# %%
calendar_listing_id_list = calendar['listing_id'].value_counts()
print(calendar_listing_id_list.shape)
print(calendar_listing_id_list.describe())
# Out:
# (3818,)
# count    3818.0
# mean      365.0
# std         0.0
# min       365.0
# 25%       365.0
# 50%       365.0
# 75%       365.0
# max       365.0
# Name: listing_id, dtype: float64

# %% [markdown]
# ###### we can get some info from calendar data :
# - there are 3818 listing ids in Calendar data
# - every listing ids have 365 days's record
# - some listing ids are NOT available all year，some are available all year

# %%
# we can get some info :
#there are 3818 listing ids
#every listing ids have 365 days's record
#some id is NOT available all year
#some id is available all year
print(calendar[calendar['listing_id']== 777159 ])
print(calendar[calendar['listing_id']== 611500 ])
calendar['listing_id'].unique().shape
# Out:
#         listing_id        date  available  price
# 832565      777159  2016-01-04          0    NaN
# 832566      777159  2016-01-05          0    NaN
# 832567      777159  2016-01-06          0    NaN
# 832568      777159  2016-01-07          0    NaN
# 832569      777159  2016-01-08          0    NaN
# 832570      777159  2016-01-09          0    NaN
# 832571      777159  2016-01-10          0    NaN
# 832572      777159  2016-01-11          0    NaN
# 832573      777159  2016-01-12          0    NaN
# 832574      777159  2016-01-13          0    NaN
# 832575      777159  2016-01-14          0    NaN
# 832576      777159  2016-01-15          0    NaN
# 832577      777159  2016-01-16          0    NaN
# 832578      777159  2016-01-17          0    NaN
# 832579      777159  2016-01-18          0    NaN
# 832580      777159  2016-01-19          0    NaN
# 832581      777159  2016-01-20          0    NaN
# 832582      777159  2016-01-21          0    NaN
# 832583      777159  2016-01-22          0    NaN
# 832584      777159  2016-01-23          0    NaN
# 832585      777159  2016-01-24          0    NaN
# 832586      777159  2016-01-25          0    NaN
# 832587      777159  2016-01-26          0    NaN
# 832588      777159  2016-01-27          0    NaN
# 832589      777159  2016-01-28          0    NaN
# 832590      777159  2016-01-29          0    NaN
# 832591      777159  2016-01-30          0    NaN
# 832592      777159  2016-01-31          0    NaN
# 832593      777159  2016-02-01          0    NaN
# 832594      777159  2016-02-02          0    NaN
# ...            ...         ...        ...    ...
# 832900      777159  2016-12-04          0    NaN
# 832901      777159  2016-12-05          0    NaN
# 832902      777159  2016-12-06          0    NaN
# 832903      777159  2016-12-07          0    NaN
# 832904      777159  2016-12-08          0    NaN
# 832905      777159  2016-12-09          0    NaN
# 832906      777159  2016-12-10          0    NaN
# 832907      777159  2016-12-11          0    NaN
# 832908      777159  2016-12-12          0    NaN
# 832909      777159  2016-12-13          0    NaN
# 832910      777159  2016-12-14          0    NaN
# 832911      777159  2016-12-15          0    NaN
# 832912      777159  2016-12-16          0    NaN
# 832913      777159  2016-12-17          0    NaN
# 832914      777159  2016-12-18          0    NaN
# 832915      777159  2016-12-19          0    NaN
# 832916      777159  2016-12-20          0    NaN
# 832917      777159  2016-12-21          0    NaN
# 832918      777159  2016-12-22          0    NaN
# 832919      777159  2016-12-23          0    NaN
# 832920      777159  2016-12-24          0    NaN
# 832921      777159  2016-12-25          0    NaN
# 832922      777159  2016-12-26          0    NaN
# 832923      777159  2016-12-27          0    NaN
# 832924      777159  2016-12-28          0    NaN
# 832925      777159  2016-12-29          0    NaN
# 832926      777159  2016-12-30          0    NaN
# 832927      777159  2016-12-31          0    NaN
# 832928      777159  2017-01-01          0    NaN
# 832929      777159  2017-01-02          0    NaN
#
# [365 rows x 4 columns]
#         listing_id        date  available  price
# 765405      611500  2016-01-04          1  219.0
# 765406      611500  2016-01-05          1  219.0
# 765407      611500  2016-01-06          1  219.0
# 765408      611500  2016-01-07          1  219.0
# 765409      611500  2016-01-08          1  249.0
# 765410      611500  2016-01-09          1  249.0
# 765411      611500  2016-01-10          1  219.0
# 765412      611500  2016-01-11          1  219.0
# 765413      611500  2016-01-12          1  219.0
# 765414      611500  2016-01-13          1  219.0
# 765415      611500  2016-01-14          1  219.0
# 765416      611500  2016-01-15          1  249.0
# 765417      611500  2016-01-16          1  249.0
# 765418      611500  2016-01-17          1  219.0
# 765419      611500  2016-01-18          1  219.0
# 765420      611500  2016-01-19          1  219.0
# 765421      611500  2016-01-20          1  219.0
# 765422      611500  2016-01-21          1  219.0
# 765423      611500  2016-01-22          1  249.0
# 765424      611500  2016-01-23          1  249.0
# 765425      611500  2016-01-24          1  219.0
# 765426      611500  2016-01-25          1  219.0
# 765427      611500  2016-01-26          1  219.0
# 765428      611500  2016-01-27          1  219.0
# 765429      611500  2016-01-28          1  219.0
# 765430      611500  2016-01-29          1  249.0
# 765431      611500  2016-01-30          1  249.0
# 765432      611500  2016-01-31          1  219.0
# 765433      611500  2016-02-01          1  219.0
# 765434      611500  2016-02-02          1  219.0
# ...            ...         ...        ...    ...
# 765740      611500  2016-12-04          1  219.0
# 765741      611500  2016-12-05          1  219.0
# 765742      611500  2016-12-06          1  219.0
# 765743      611500  2016-12-07          1  219.0
# 765744      611500  2016-12-08          1  219.0
# 765745      611500  2016-12-09          1  249.0
# 765746      611500  2016-12-10          1  249.0
# 765747      611500  2016-12-11          1  219.0
# 765748      611500  2016-12-12          1  219.0
# 765749      611500  2016-12-13          1  219.0
# 765750      611500  2016-12-14          1  219.0
# 765751      611500  2016-12-15          1  219.0
# 765752      611500  2016-12-16          1  249.0
# 765753      611500  2016-12-17          1  249.0
# 765754      611500  2016-12-18          1  219.0
# 765755      611500  2016-12-19          1  219.0
# 765756      611500  2016-12-20          1  219.0
# 765757      611500  2016-12-21          1  219.0
# 765758      611500  2016-12-22          1  219.0
# 765759      611500  2016-12-23          1  249.0
# 765760      611500  2016-12-24          1  249.0
# 765761      611500  2016-12-25          1  219.0
# 765762      611500  2016-12-26          1  219.0
# 765763      611500  2016-12-27          1  219.0
# 765764      611500  2016-12-28          1  219.0
# 765765      611500  2016-12-29          1  219.0
# 765766      611500  2016-12-30          1  249.0
# 765767      611500  2016-12-31          1  249.0
# 765768      611500  2017-01-01          1  219.0
# 765769      611500  2017-01-02          1  219.0
#
# [365 rows x 4 columns]
# (3818,)

# %%
available_days = {}
available_days['listing_id'] = []
available_days['days'] = []

# %%
for i in range(0, calendar_listing_id_list.shape[0]):
    sample = calendar.loc[calendar['listing_id'] == calendar_listing_id_list.index[i] ]
    available_days['listing_id'].append(calendar_listing_id_list.index[i])
    available_days['days'].append(sample['price'].notnull().sum())

# %%
df1 = pd.DataFrame(available_days )
df1.sort_values('days',axis = 0,ascending = True)
data = df1['days']
mean_days = df1['days'].mean()
plt.bar(range(len(data)), data)
plt.title("available days")

y=mean_days
plt.hlines(y, 0, 3800)
plt.show()

# %%
print(reviews.columns)
print(reviews.shape)
print(reviews.dtypes)
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')
# (84849, 6)
# listing_id        int64
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object

# %%
#are all reviews data's listing_ids  in calendar data's listing_ids?
#answer is yes!
def find_listing_id( raw ):
    if raw.listing_id in calendar_listing_id_list.index:
        return True
    else:
        return False
finding_list = reviews.apply(find_listing_id, axis = 1)
print("Are all reviews data's listing ids in calendar data's listing ids? Answer is : {}".format(finding_list.value_counts().sum() == reviews.shape[0]))
# Out:
# Are all reviews data's listing ids in calendar data's listing ids? Answer is : True

# %% [markdown]
# ##### Are all reviews data's listing ids in calendar data's listing ids? Answer is : True

# %%
listing_data_id_list = listings['id'].unique()
print(len(listing_data_id_list))
# Out:
# 3818

# %%
#are all listing data's listing_ids  in reviews data's listing_ids?
#answer is yes!
reviews_listing_id_list = reviews['listing_id'].value_counts()
def find_listing_id_2( raw ):
    if raw.id in reviews_listing_id_list.index:
        return True
    else:
        return False
finding_list = listings.apply(find_listing_id_2, axis = 1)
finding_list.describe()
finding_list.value_counts()
#print("Are all listing data's ids in reviews data's listing ids? Answer is : {}".format(finding_list.value_counts().sum() == reviews_listing_id_list.shape[0]))
# Out:
# True     3191
# False     627
# dtype: int64

# %% [markdown]
# ##### Are all listing data's ids in review data's listing ids? Answer is : False

# %%
reviews_listing_id_list = reviews['listing_id'].value_counts()
missed_listing_id_list = list()
for i in range(0,calendar_listing_id_list.shape[0] ):
    if calendar_listing_id_list.index[i] not in reviews_listing_id_list.index:
        missed_listing_id_list.append(calendar_listing_id_list.index[i] )

missed_listing_id_df = pd.DataFrame({"listing_id":missed_listing_id_list} ,columns=['listing_id'], dtype=np.int64)
print(missed_listing_id_df.shape)
# Out:
# (627, 1)

# %%
#reviews[reviews['listing_id'] == 9497431]
for i in range(0,missed_listing_id_df.shape[0]):
    x = missed_listing_id_df['listing_id'][i]
    print("listing id: {} available days: {}".format(x, aa_available_days[x] ) )
# Out:
# listing id: 10310373 available days: 351
# listing id: 9280767 available days: 356
# listing id: 9910189 available days: 0
# listing id: 8989807 available days: 27
# listing id: 9497431 available days: 135
# listing id: 9480029 available days: 365
# listing id: 4075152 available days: 6
# listing id: 8107555 available days: 95
# listing id: 8156894 available days: 365
# listing id: 10060388 available days: 58
# listing id: 9961388 available days: 27
# listing id: 10299108 available days: 65
# listing id: 6694276 available days: 365
# listing id: 9288840 available days: 34
# listing id: 9999955 available days: 350
# listing id: 8503556 available days: 316
# listing id: 10234558 available days: 355
# listing id: 2729077 available days: 302
# listing id: 7501583 available days: 139
# listing id: 9921445 available days: 365
# listing id: 10124808 available days: 339
# listing id: 8674765 available days: 334
# listing id: 8555794 available days: 365
# listing id: 7984738 available days: 365
# listing id: 9435279 available days: 365
# listing id: 9693971 available days: 365
# listing id: 9078843 available days: 365
# listing id: 5422881 available days: 126
# listing id: 6916167 available days: 365
# listing id: 9717757 available days: 178
# listing id: 10267360 available days: 88
# listing id: 4163204 available days: 365
# listing id: 6867053 available days: 277
# listing id: 37234 available days: 311
# listing id: 7009282 available days: 365
# listing id: 6572501 available days: 365
# listing id: 341454 available days: 318
# listing id: 10204689 available days: 22
# listing id: 8811945 available days: 0
# listing id: 8000037 available days: 109
# listing id: 10108451 available days: 8
# listing id: 4084398 available days: 226
# listing id: 7901725 available days: 114
# listing id: 10136155 available days: 45
# listing id: 3282760 available days: 365
# listing id: 8953857 available days: 277
# listing id: 9371895 available days: 2
# listing id: 9994758 available days: 82
# listing id: 8089214 available days: 365
# listing id: 9796540 available days: 326
# listing id: 1761870 available days: 94
# listing id: 8428825 available days: 83
# listing id: 10340165 available days: 358
# listing id: 9432322 available days: 29
# listing id: 8326940 available days: 364
# listing id: 4135710 available days: 140
# listing id: 9186681 available days: 65
# listing id: 7843837 available days: 183
# listing id: 10022421 available days: 89
# listing id: 10319529 available days: 1
# listing id: 9797545 available days: 310
# listing id: 3335 available days: 309
# listing id: 9137259 available days: 353
# listing id: 7988792 available days: 109
# listing id: 9685856 available days: 365
# listing id: 8156860 available days: 365
# listing id: 10229434 available days: 362
# listing id: 4395349 available days: 365
# listing id: 4182732 available days: 365
# listing id: 9186481 available days: 148
# listing id: 8922153 available days: 55
# listing id: 9252998 available days: 38
# listing id: 10211928 available days: 365
# listing id: 8717758 available days: 358
# listing id: 9509695 available days: 22
# listing id: 671828 available days: 338
# listing id: 5020848 available days: 365
# listing id: 6689259 available days: 305
# listing id: 10157690 available days: 76
# listing id: 9061439 available days: 61
# listing id: 10104370 available days: 5
# listing id: 4566393 available days: 365
# listing id: 2387265 available days: 89
# listing id: 10123910 available days: 365
# listing id: 4597013 available days: 365
# listing id: 8207987 available days: 365
# listing id: 8156764 available days: 338
# listing id: 10139271 available days: 356
# listing id: 9168049 available days: 351
# listing id: 9546633 available days: 338
# listing id: 8327765 available days: 364
# listing id: 8441263 available days: 0
# listing id: 170469 available days: 359
# listing id: 9138392 available days: 45
# listing id: 9597947 available days: 365
# listing id: 9925458 available days: 365
# listing id: 7580593 available days: 2
# listing id: 3584790 available days: 2
# listing id: 9463729 available days: 364
# listing id: 5593981 available days: 65
# listing id: 9939740 available days: 81
# listing id: 9664395 available days: 16
# listing id: 10122924 available days: 365
# listing id: 1885801 available days: 364
# listing id: 9591718 available days: 365
# listing id: 4401544 available days: 38
# listing id: 9116815 available days: 337
# listing id: 10210971 available days: 363
# listing id: 7021702 available days: 166
# listing id: 7228435 available days: 216
# listing id: 9137335 available days: 356
# listing id: 9449437 available days: 232
# listing id: 7279669 available days: 152
# listing id: 9666446 available days: 354
# listing id: 3529563 available days: 365
# listing id: 9149612 available days: 2
# listing id: 4395502 available days: 365
# listing id: 7952032 available days: 0
# listing id: 2426152 available days: 0
# listing id: 9189391 available days: 365
# listing id: 10026648 available days: 13
# listing id: 9094366 available days: 45
# listing id: 3753645 available days: 211
# listing id: 9609152 available days: 364
# listing id: 10125020 available days: 357
# listing id: 8354452 available days: 89
# listing id: 8308386 available days: 361
# listing id: 8132347 available days: 270
# listing id: 10036903 available days: 111
# listing id: 9237535 available days: 362
# listing id: 8289871 available days: 365
# listing id: 8048333 available days: 337
# listing id: 9531265 available days: 365
# listing id: 9675736 available days: 150
# listing id: 9370738 available days: 264
# listing id: 7717653 available days: 133
# listing id: 10292753 available days: 152
# listing id: 10126050 available days: 28
# listing id: 8373832 available days: 362
# listing id: 8596938 available days: 72
# listing id: 8784239 available days: 365
# listing id: 7035077 available days: 365
# listing id: 9137398 available days: 355
# listing id: 8446347 available days: 365
# listing id: 9938792 available days: 347
# listing id: 9591787 available days: 361
# listing id: 9888395 available days: 4
# listing id: 7151093 available days: 365
# listing id: 8735996 available days: 65
# listing id: 6169489 available days: 227
# listing id: 8868025 available days: 365
# listing id: 7405128 available days: 277
# listing id: 9492036 available days: 22
# listing id: 10334184 available days: 361
# listing id: 5192122 available days: 306
# listing id: 8849596 available days: 58
# listing id: 8882345 available days: 287
# listing id: 9733835 available days: 27
# listing id: 9712348 available days: 197
# listing id: 7938941 available days: 364
# listing id: 9370007 available days: 309
# listing id: 8606766 available days: 180
# listing id: 7513623 available days: 332
# listing id: 8286095 available days: 350
# listing id: 9858690 available days: 365
# listing id: 7480843 available days: 365
# listing id: 7936877 available days: 113
# listing id: 9577993 available days: 17
# listing id: 9866909 available days: 360
# listing id: 9159975 available days: 365
# listing id: 6915439 available days: 19
# listing id: 10332096 available days: 365
# listing id: 5619397 available days: 365
# listing id: 10281965 available days: 356
# listing id: 9545281 available days: 20
# listing id: 9219567 available days: 315
# listing id: 9352620 available days: 186
# listing id: 5930806 available days: 356
# listing id: 8829089 available days: 365
# listing id: 8091417 available days: 103
# listing id: 9768655 available days: 360
# listing id: 8053554 available days: 105
# listing id: 9199082 available days: 39
# listing id: 10157880 available days: 66
# listing id: 9196007 available days: 14
# listing id: 10272763 available days: 365
# listing id: 9733841 available days: 324
# listing id: 10231701 available days: 176
# listing id: 5204475 available days: 313
# listing id: 9319891 available days: 278
# listing id: 9220485 available days: 59
# listing id: 4310055 available days: 179
# listing id: 9136499 available days: 42
# listing id: 9014572 available days: 365
# listing id: 8901863 available days: 365
# listing id: 9505340 available days: 268
# listing id: 5707514 available days: 365
# listing id: 9843421 available days: 2
# listing id: 9407989 available days: 28
# listing id: 9813684 available days: 365
# listing id: 9318853 available days: 32
# listing id: 7035240 available days: 165
# listing id: 8814802 available days: 365
# listing id: 8306646 available days: 364
# listing id: 9331145 available days: 32
# listing id: 9095510 available days: 365
# listing id: 10279830 available days: 337
# listing id: 9169270 available days: 78
# listing id: 8865006 available days: 77
# listing id: 9410043 available days: 9
# listing id: 10135378 available days: 13
# listing id: 8537192 available days: 247
# listing id: 9618016 available days: 15
# listing id: 354453 available days: 365
# listing id: 8292326 available days: 365
# listing id: 7921453 available days: 365
# listing id: 9532957 available days: 20
# listing id: 8699046 available days: 67
# listing id: 4824435 available days: 14
# listing id: 9822848 available days: 5
# listing id: 10126199 available days: 88
# listing id: 9462315 available days: 365
# listing id: 8118110 available days: 89
# listing id: 9137487 available days: 42
# listing id: 10183490 available days: 365
# listing id: 9304465 available days: 19
# listing id: 9408991 available days: 28
# listing id: 9475641 available days: 79
# listing id: 5059981 available days: 328
# listing id: 8443952 available days: 89
# listing id: 7948034 available days: 365
# listing id: 9781881 available days: 246
# listing id: 9236814 available days: 47
# listing id: 9171373 available days: 20
# listing id: 9463491 available days: 365
# listing id: 10295151 available days: 357
# listing id: 8241019 available days: 0
# listing id: 4903296 available days: 179
# listing id: 8225635 available days: 365
# listing id: 9511676 available days: 98
# listing id: 9604740 available days: 179
# listing id: 5270223 available days: 307
# listing id: 9908825 available days: 309
# listing id: 9348375 available days: 30
# listing id: 6769696 available days: 338
# listing id: 9476826 available days: 365
# listing id: 9696950 available days: 365
# listing id: 6850007 available days: 365
# listing id: 9521903 available days: 308
# listing id: 8782852 available days: 35
# listing id: 10252110 available days: 19
# listing id: 10140582 available days: 16
# listing id: 10339145 available days: 365
# listing id: 10339144 available days: 0
# listing id: 8356608 available days: 365
# listing id: 9634448 available days: 358
# listing id: 10031055 available days: 82
# listing id: 9696912 available days: 89
# listing id: 10132385 available days: 348
# listing id: 10077121 available days: 357
# listing id: 10135468 available days: 338
# listing id: 9033154 available days: 48
# listing id: 9580209 available days: 365
# listing id: 9716348 available days: 9
# listing id: 9885225 available days: 126
# listing id: 9736801 available days: 365
# listing id: 7011773 available days: 55
# listing id: 9516743 available days: 21
# listing id: 7717478 available days: 198
# listing id: 7229743 available days: 20
# listing id: 8101791 available days: 361
# listing id: 9258305 available days: 179
# listing id: 7922676 available days: 0
# listing id: 8194886 available days: 0
# listing id: 3922845 available days: 247
# listing id: 5241195 available days: 338
# listing id: 8957312 available days: 364
# listing id: 10188794 available days: 34
# listing id: 9174507 available days: 365
# listing id: 6438099 available days: 324
# listing id: 3759039 available days: 0
# listing id: 9836113 available days: 321
# listing id: 6854019 available days: 176
# listing id: 4334804 available days: 311
# listing id: 4638785 available days: 358
# listing id: 8267620 available days: 364
# listing id: 6537432 available days: 223
# listing id: 10299195 available days: 14
# listing id: 9663221 available days: 365
# listing id: 9822759 available days: 4
# listing id: 9974658 available days: 59
# listing id: 10000273 available days: 346
# listing id: 9513636 available days: 364
# listing id: 8339303 available days: 336
# listing id: 9241055 available days: 35
# listing id: 9732638 available days: 308
# listing id: 6729818 available days: 184
# listing id: 9342299 available days: 365
# listing id: 8541389 available days: 365
# listing id: 8446120 available days: 365
# listing id: 10020782 available days: 0
# listing id: 10060674 available days: 3
# listing id: 8196883 available days: 108
# listing id: 9922140 available days: 59
# listing id: 9490093 available days: 89
# listing id: 10068879 available days: 365
# listing id: 10265391 available days: 362
# listing id: 9457328 available days: 346
# listing id: 9970609 available days: 365
# listing id: 270370 available days: 69
# listing id: 9368950 available days: 365
# listing id: 8831088 available days: 59
# listing id: 8715320 available days: 184
# listing id: 7838294 available days: 119
# listing id: 9435483 available days: 365
# listing id: 7761509 available days: 52
# listing id: 5482204 available days: 275
# listing id: 9217337 available days: 364
# listing id: 9095668 available days: 0
# listing id: 5814207 available days: 256
# listing id: 10076279 available days: 11
# listing id: 9835920 available days: 358
# listing id: 8484705 available days: 356
# listing id: 5015262 available days: 333
# listing id: 9757138 available days: 27
# listing id: 6704004 available days: 163
# listing id: 8988281 available days: 48
# listing id: 10191917 available days: 37
# listing id: 6516529 available days: 199
# listing id: 5036739 available days: 331
# listing id: 9619737 available days: 337
# listing id: 9961538 available days: 51
# listing id: 9202380 available days: 358
# listing id: 9416373 available days: 365
# listing id: 9097754 available days: 89
# listing id: 10121329 available days: 364
# listing id: 8099917 available days: 294
# listing id: 9048584 available days: 365
# listing id: 3883041 available days: 365
# listing id: 4824699 available days: 365
# listing id: 3738724 available days: 365
# listing id: 7665114 available days: 146
# listing id: 6481695 available days: 364
# listing id: 8704964 available days: 365
# listing id: 8799162 available days: 89
# listing id: 9628972 available days: 73
# listing id: 10035274 available days: 0
# listing id: 9313974 available days: 85
# listing id: 10043487 available days: 365
# listing id: 7678429 available days: 129
# listing id: 9316009 available days: 32
# listing id: 7093986 available days: 20
# listing id: 7762347 available days: 124
# listing id: 7258811 available days: 365
# listing id: 9812439 available days: 77
# listing id: 9878971 available days: 25
# listing id: 9696532 available days: 179
# listing id: 9573675 available days: 365
# listing id: 9229043 available days: 364
# listing id: 8969737 available days: 52
# listing id: 6228211 available days: 222
# listing id: 9410302 available days: 365
# listing id: 5738982 available days: 262
# listing id: 4651974 available days: 77
# listing id: 9258687 available days: 34
# listing id: 9117301 available days: 61
# listing id: 8814555 available days: 61
# listing id: 10211716 available days: 364
# listing id: 10235014 available days: 3
# listing id: 10156116 available days: 365
# listing id: 7824870 available days: 120
# listing id: 9448719 available days: 365
# listing id: 408526 available days: 365
# listing id: 7902229 available days: 70
# listing id: 8118346 available days: 365
# listing id: 9351911 available days: 365
# listing id: 8131762 available days: 271
# listing id: 8170683 available days: 365
# listing id: 6911511 available days: 145
# listing id: 9025039 available days: 49
# listing id: 5863446 available days: 312
# listing id: 8845310 available days: 303
# listing id: 4833820 available days: 331
# listing id: 9409233 available days: 365
# listing id: 8233110 available days: 361
# listing id: 8668073 available days: 365
# listing id: 8069192 available days: 338
# listing id: 8849407 available days: 365
# listing id: 8780704 available days: 346
# listing id: 7885859 available days: 115
# listing id: 9345786 available days: 365
# listing id: 911001 available days: 235
# listing id: 9715029 available days: 298
# listing id: 9530877 available days: 143
# listing id: 9814376 available days: 365
# listing id: 9050781 available days: 162
# listing id: 3889330 available days: 364
# listing id: 9023202 available days: 49
# listing id: 4379551 available days: 82
# listing id: 8474605 available days: 365
# listing id: 2208757 available days: 10
# listing id: 10015967 available days: 0
# listing id: 10205366 available days: 126
# listing id: 10331249 available days: 354
# listing id: 8742753 available days: 365
# listing id: 7957729 available days: 102
# listing id: 284480 available days: 273
# listing id: 4596493 available days: 44
# listing id: 8968925 available days: 365
# listing id: 7437784 available days: 0
# listing id: 8670079 available days: 69
# listing id: 9846066 available days: 350
# listing id: 8154238 available days: 365
# listing id: 7275027 available days: 121
# listing id: 9863457 available days: 365
# listing id: 7727428 available days: 126
# listing id: 7302675 available days: 150
# listing id: 9883943 available days: 350
# listing id: 9900319 available days: 5
# listing id: 7584142 available days: 365
# listing id: 10141859 available days: 365
# listing id: 1818754 available days: 83
# listing id: 6492056 available days: 202
# listing id: 9636248 available days: 359
# listing id: 9636238 available days: 4
# listing id: 8626068 available days: 71
# listing id: 9562586 available days: 0
# listing id: 9133711 available days: 351
# listing id: 8322107 available days: 90
# listing id: 9028315 available days: 365
# listing id: 8907548 available days: 365
# listing id: 745099 available days: 337
# listing id: 9774404 available days: 7
# listing id: 9868607 available days: 1
# listing id: 8459215 available days: 365
# listing id: 9900303 available days: 0
# listing id: 3889280 available days: 365
# listing id: 4066344 available days: 365
# listing id: 68508 available days: 308
# listing id: 5102135 available days: 324
# listing id: 7651602 available days: 365
# listing id: 9530788 available days: 65
# listing id: 6627129 available days: 192
# listing id: 9158383 available days: 41
# listing id: 4597584 available days: 365
# listing id: 8722230 available days: 331
# listing id: 7577073 available days: 365
# listing id: 10106055 available days: 365
# listing id: 9094872 available days: 365
# listing id: 8129537 available days: 100
# listing id: 9563458 available days: 247
# listing id: 9738522 available days: 358
# listing id: 9240289 available days: 36
# listing id: 2808357 available days: 0
# listing id: 9887142 available days: 70
# listing id: 4403171 available days: 365
# listing id: 8845144 available days: 365
# listing id: 9710851 available days: 303
# listing id: 9920856 available days: 365
# listing id: 4252591 available days: 365
# listing id: 6290509 available days: 347
# listing id: 9679300 available days: 362
# listing id: 8766231 available days: 120
# listing id: 8828781 available days: 83
# listing id: 149489 available days: 365
# listing id: 9258513 available days: 336
# listing id: 10170577 available days: 365
# listing id: 3931346 available days: 365
# listing id: 9410128 available days: 28
# listing id: 9444769 available days: 324
# listing id: 8785768 available days: 331
# listing id: 9597415 available days: 16
# listing id: 9739482 available days: 362
# listing id: 9477204 available days: 23
# listing id: 8714974 available days: 365
# listing id: 9332620 available days: 93
# listing id: 9976135 available days: 10
# listing id: 4950847 available days: 365
# listing id: 9067268 available days: 61
# listing id: 8538630 available days: 247
# listing id: 8689375 available days: 361
# listing id: 2958318 available days: 2
# listing id: 9296887 available days: 247
# listing id: 9863312 available days: 365
# listing id: 6865696 available days: 365
# listing id: 7562331 available days: 329
# listing id: 10210625 available days: 1
# listing id: 9030406 available days: 347
# listing id: 9496612 available days: 22
# listing id: 9636952 available days: 365
# listing id: 9254900 available days: 29
# listing id: 9693230 available days: 23
# listing id: 4199019 available days: 358
# listing id: 2467550 available days: 48
# listing id: 7735464 available days: 125
# listing id: 9907337 available days: 365
# listing id: 8799909 available days: 61
# listing id: 7748778 available days: 365
# listing id: 8820414 available days: 247
# listing id: 9369481 available days: 365
# listing id: 7177194 available days: 334
# listing id: 8525338 available days: 337
# listing id: 9813231 available days: 365
# listing id: 6315614 available days: 216
# listing id: 8409695 available days: 365
# listing id: 10211609 available days: 359
# listing id: 8116504 available days: 365
# listing id: 10250735 available days: 4
# listing id: 8106263 available days: 336
# listing id: 9696286 available days: 32
# listing id: 8431178 available days: 363
# listing id: 8555098 available days: 365
# listing id: 9635943 available days: 365
# listing id: 9068366 available days: 46
# listing id: 8724134 available days: 365
# listing id: 8402434 available days: 112
# listing id: 9098059 available days: 17
# listing id: 3404914 available days: 212
# listing id: 8411663 available days: 178
# listing id: 9474025 available days: 365
# listing id: 4787415 available days: 364
# listing id: 9545664 available days: 365
# listing id: 9922335 available days: 362
# listing id: 9395217 available days: 309
# listing id: 8764748 available days: 360
# listing id: 8371720 available days: 365
# listing id: 9328692 available days: 133
# listing id: 9901852 available days: 71
# listing id: 10262971 available days: 365
# listing id: 8849095 available days: 45
# listing id: 9975073 available days: 0
# listing id: 7421966 available days: 143
# listing id: 10192213 available days: 365
# listing id: 9909445 available days: 82
# listing id: 9368573 available days: 362
# listing id: 9155422 available days: 365
# listing id: 7743727 available days: 121
# listing id: 6584984 available days: 195
# listing id: 10208623 available days: 7
# listing id: 9550869 available days: 354
# listing id: 10019082 available days: 89
# listing id: 9545766 available days: 365
# listing id: 8943380 available days: 363
# listing id: 9699490 available days: 0
# listing id: 9576550 available days: 18
# listing id: 9886971 available days: 234
# listing id: 4190689 available days: 227
# listing id: 10273158 available days: 352
# listing id: 10170744 available days: 364
# listing id: 9368517 available days: 30
# listing id: 9109293 available days: 179
# listing id: 9600159 available days: 16
# listing id: 609252 available days: 365
# listing id: 9299824 available days: 324
# listing id: 8886847 available days: 365
# listing id: 4130102 available days: 107
# listing id: 8570596 available days: 352
# listing id: 10249527 available days: 7
# listing id: 4995903 available days: 60
# listing id: 9979329 available days: 365
# listing id: 9611409 available days: 88
# listing id: 9368342 available days: 212
# listing id: 8209686 available days: 93
# listing id: 6897639 available days: 174
# listing id: 9063355 available days: 89
# listing id: 8866331 available days: 337
# listing id: 4494947 available days: 344
# listing id: 8257837 available days: 279
# listing id: 8703557 available days: 365
# listing id: 8608414 available days: 72
# listing id: 9314106 available days: 38
# listing id: 8718936 available days: 360
# listing id: 10318171 available days: 364
# listing id: 9460991 available days: 365
# listing id: 8575663 available days: 142
# listing id: 8562314 available days: 247
# listing id: 9137075 available days: 356
# listing id: 8427254 available days: 303
# listing id: 9110410 available days: 277
# listing id: 10274175 available days: 345
# listing id: 9407255 available days: 166
# listing id: 8842808 available days: 365
# listing id: 5950957 available days: 365
# listing id: 9574602 available days: 365
# listing id: 10235136 available days: 1
# listing id: 7109376 available days: 350
# listing id: 4659824 available days: 364
# listing id: 9416551 available days: 340
# listing id: 9364302 available days: 0
# listing id: 6005222 available days: 365
# listing id: 8087037 available days: 365
# listing id: 704477 available days: 88
# listing id: 6882211 available days: 124
# listing id: 9516114 available days: 21
# listing id: 9595087 available days: 308
# listing id: 9880665 available days: 364
# listing id: 8253758 available days: 0
# listing id: 9415562 available days: 365
# listing id: 9695233 available days: 365
# listing id: 9939038 available days: 80
# listing id: 8409773 available days: 303
# listing id: 10023353 available days: 223
# listing id: 7999972 available days: 109
# listing id: 8566501 available days: 365
# listing id: 7180032 available days: 69
# listing id: 6342327 available days: 0
# listing id: 8847951 available days: 116
# listing id: 4809601 available days: 365
# listing id: 8984454 available days: 51
# listing id: 8474253 available days: 11
# listing id: 4507137 available days: 0
# listing id: 1686958 available days: 184
# listing id: 9282348 available days: 34
# listing id: 10035644 available days: 278
# listing id: 6704734 available days: 277
# listing id: 10247453 available days: 362
# listing id: 8173825 available days: 98
# listing id: 1317919 available days: 365
# listing id: 9939025 available days: 0
# listing id: 9117633 available days: 37
# listing id: 8157486 available days: 365
# listing id: 10309898 available days: 365
# listing id: 8566475 available days: 345
# listing id: 9999759 available days: 61
# listing id: 9048029 available days: 365
# listing id: 7984550 available days: 365
# listing id: 9484823 available days: 365

# %%
print("We get {} listing ids in calendar data but NOT in reviews data".format( missed_listing_id_df.shape[0]))
print("It seems not all ")
# Out:
# We get 627 listing ids in calendar data but NOT in reviews data
# Most of these listing datas are available

# %%
print((listings.isnull().sum()/len(listings)).sort_values(ascending=False))
# Out:
# license             1.000000
# square_feet         0.974594
# monthly_price       0.602672
# security_deposit    0.511262
# weekly_price        0.473808
#                       ...
# accommodates        0.000000
# bed_type            0.000000
# amenities           0.000000
# price               0.000000
# id                  0.000000
# Length: 92, dtype: float64

# %%
#
listings_mis_columns = listings.columns[listings.isnull().sum()/len(listings) > 0.2 ].sort_values(ascending=False)
listings_mis_columns
# Out:
# Index(['weekly_price', 'transit', 'square_feet', 'security_deposit', 'notes',
#        'neighborhood_overview', 'monthly_price', 'license',
#        'host_acceptance_rate', 'host_about', 'cleaning_fee'],
#       dtype='object')

# %%
(listings[['weekly_price', 'transit', 'square_feet', 'security_deposit', 'notes',
       'neighborhood_overview', 'monthly_price', 'license',
       'host_acceptance_rate', 'host_about', 'cleaning_fee']].isnull().sum()/len(listings)).sort_values(ascending=False)
# Out:
# license                  1.000000
# square_feet              0.974594
# monthly_price            0.602672
# security_deposit         0.511262
# weekly_price             0.473808
# notes                    0.420639
# neighborhood_overview    0.270299
# cleaning_fee             0.269775
# transit                  0.244631
# host_about               0.224987
# host_acceptance_rate     0.202462
# dtype: float64

# %%
#we should drop some columns,their missing value is greater than 30%
# weekly_price is 
listings[['price','weekly_price', 'transit', 'square_feet', 'security_deposit', 'notes',
       'neighborhood_overview', 'monthly_price', 'license',
       'host_acceptance_rate', 'host_about', 'cleaning_fee']].head(10)
# Out:
#      price weekly_price                                            transit  \
# 0   $85.00          NaN                                                NaN
# 1  $150.00    $1,000.00  Convenient bus stops are just down the block, ...
# 2  $975.00          NaN  A bus stop is just 2 blocks away.   Easy bus a...
# 3  $100.00      $650.00                                                NaN
# 4  $450.00          NaN  The nearest public transit bus (D Line) is 2 b...
# 5  $120.00      $800.00  The #1 and #2 bus picks up 2-3 blocks away (di...
# 6   $80.00      $575.00  The bus goes through the lower Queen Anne neig...
# 7   $60.00      $360.00     the "D" line runs out in front of our house .
# 8   $90.00      $500.00  Bus stop to downtown directly across the stree...
# 9  $150.00    $1,000.00  Convenient bus stops are just down the block, ...
#
#    square_feet security_deposit  \
# 0          NaN              NaN
# 1          NaN          $100.00
# 2          NaN        $1,000.00
# 3          NaN              NaN
# 4          NaN          $700.00
# 5          NaN              NaN
# 6          NaN          $150.00
# 7          NaN          $150.00
# 8          NaN              NaN
# 9          NaN          $100.00
#
#                                                notes  \
# 0                                                NaN
# 1  What's up with the free pillows?  Our home was...
# 2  Our house is located just 5 short blocks to To...
# 3                                                NaN
# 4                                          Belltown
# 5  Let me know if you need anything or have sugge...
# 6  The room now has a mini frig to keep your favo...
# 7  There are three rentals in our back yard . If ...
# 8                                                NaN
# 9  What's up with the free pillows?  Our home was...
#
#                                neighborhood_overview monthly_price  license  \
# 0                                                NaN           NaN      NaN
# 1  Queen Anne is a wonderful, truly functional vi...     $3,000.00      NaN
# 2  Upper Queen Anne is a charming neighborhood fu...           NaN      NaN
# 3                                                NaN     $2,300.00      NaN
# 4  We are in the beautiful neighborhood of Queen ...           NaN      NaN
# 5  This part of Queen Anne has wonderful views an...           NaN      NaN
# 6  Close restaurants, coffee shops and grocery st...           NaN      NaN
# 7  We are centrally located between Downtown and ...           NaN      NaN
# 8  Walking Score: 92 4 blocks from Kerry Park Fam...     $1,700.00      NaN
# 9  Queen Anne is a wonderful, truly functional vi...     $3,000.00      NaN
#
#   host_acceptance_rate                                         host_about  \
# 0                 100%  I am an artist, interior designer, and run a s...
# 1                 100%  Living east coast/left coast/overseas.  Time i...
# 2                 100%  i love living in Seattle.  i grew up in the mi...
# 3                  NaN                                                NaN
# 4                  NaN  Hi, I live in Seattle, Washington but I'm orig...
# 5                  NaN  I've been fortunate to have had many life expe...
# 6                 100%  We have lived in the the Queen Anne neighborho...
# 7                 100%  I am a carpenter at heart , I love music , I p...
# 8                 100%  I'm a 35 year old professional from Seattle, W...
# 9                 100%  Living east coast/left coast/overseas.  Time i...
#
#   cleaning_fee
# 0          NaN
# 1       $40.00
# 2      $300.00
# 3          NaN
# 4      $125.00
# 5       $40.00
# 6          NaN
# 7       $25.00
# 8          NaN
# 9       $40.00
